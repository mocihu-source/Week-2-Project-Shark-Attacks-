# %%
# !pip install pandas openpyxl xlrd
# Out:
# Requirement already satisfied: pandas in c:\users\mocim\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: openpyxl in c:\users\mocim\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: xlrd in c:\users\mocim\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mocim\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mocim\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mocim\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mocim\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\mocim\anaconda3\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\mocim\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
data = pd.read_excel("C:/Users/mocim/OneDrive/Desktop/Lessons/Week 2/Project/raw_data_shark_attacks.xls")

# %%
df = data[["Country", "Activity", "Location", "Sex", "Fatal Y/N", "Species ", "Type"]]

# %%
df.columns = df.columns.str.strip()

# %%
df.shape
# Out:
# (7097, 7)

# %%
df.tail()
# Out:
#                  Country      Activity                             Location  \
# 7092           AUSTRALIA        Diving                          Roebuck Bay
# 7093           AUSTRALIA  Pearl diving                                  NaN
# 7094                 USA      Swimming                       Ocracoke Inlet
# 7095              PANAMA           NaN                 Panama Bay 8ºN, 79ºW
# 7096  CEYLON (SRI LANKA)      Swimming  Below the English fort, Trincomalee
#
#      Sex Fatal Y/N Species        Type
# 7092   M         Y     NaN  Unprovoked
# 7093   M         Y     NaN  Unprovoked
# 7094   M         Y     NaN  Unprovoked
# 7095   M         Y     NaN  Unprovoked
# 7096   M         Y     NaN  Unprovoked

# %% [markdown]
# ### MOCI

# %%
df.isna().sum()/len(df) *100
# Out:
# Country       0.704523
# Activity      8.214739
# Location      7.989291
# Sex           8.144286
# Fatal Y/N     7.904748
# Species      44.117233
# Type          0.253628
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7097 entries, 0 to 7096
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    7047 non-null   object
#  1   Activity   6514 non-null   object
#  2   Location   6530 non-null   object
#  3   Sex        6519 non-null   object
#  4   Fatal Y/N  6536 non-null   object
#  5   Species    3966 non-null   object
#  6   Type       7079 non-null   object
# dtypes: object(7)
# memory usage: 388.2+ KB

# %% [markdown]
# - Replace null values for Unknown for Activity, Sex and Fatal Y/N as they are around 8%

# %%
df[["Activity", "Sex", "Fatal Y/N"]] = df[["Activity", "Sex", "Fatal Y/N"]].fillna("Unknown")
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\3811356152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Activity", "Sex", "Fatal Y/N"]] = df[["Activity", "Sex", "Fatal Y/N"]].fillna("Unknown")

# %% [markdown]
# - Check duplicates

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(325)

# %%
df["Sex"].value_counts()
# Out:
# Sex
# M          5689
# F           812
# Unknown     578
# M             6
# ?             2
# F             2
# N             2
# M F           1
#  M            1
# m             1
# lli           1
# M x 2         1
# .             1
# Name: count, dtype: int64

# %% [markdown]
# - Check inconsistent values

# %%
df ["Sex"] = df ["Sex"].str.strip()
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\3234921729.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df ["Sex"] = df ["Sex"].str.strip()

# %%
df ["Sex"] = df ["Sex"].str.upper()
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\3511102203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df ["Sex"] = df ["Sex"].str.upper()

# %%
df ["Sex"] = df ["Sex"].replace (["?", "UNKNOWN", "N", "M F", "LLI", ".", "M X 2"], "Unknown")
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\2089057638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df ["Sex"] = df ["Sex"].replace (["?", "UNKNOWN", "N", "M F", "LLI", ".", "M X 2"], "Unknown")

# %%
df["Activity"].nunique()
# Out:
# 1614

# %%
df["Activity"].value_counts().head(30)
# Out:
# Activity
# Surfing            1153
# Swimming           1018
# Unknown             586
# Fishing             494
# Spearfishing        393
# Wading              178
# Bathing             164
# Diving              151
# Snorkeling          135
# Standing            113
# Scuba diving         84
# Body boarding        63
# Body surfing         50
# Swimming             47
# Boogie boarding      42
# Kayaking             41
# Free diving          33
# Treading water       33
# Fell overboard       32
# Pearl diving         32
# Windsurfing          20
# Boogie Boarding      18
# Walking              17
# Fishing              16
# Floating             16
# Canoeing             16
# Shark fishing        15
# Surf fishing         14
# Surf-skiing          13
# Scuba Diving         13
# Name: count, dtype: int64

# %%
df["Activity"].value_counts().info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1614 entries, Surfing to Wreck of  large double sailing canoe
# Series name: count
# Non-Null Count  Dtype
# --------------  -----
# 1614 non-null   int64
# dtypes: int64(1)
# memory usage: 25.2+ KB

# %%
df["Activity"] = df["Activity"].str.strip().str.lower()
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\3029557794.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Activity"] = df["Activity"].str.strip().str.lower()

# %%
df["Activity"].isna().sum()
# Out:
# np.int64(0)

# %%
df.loc[df["Activity"].str.contains("surf|Boarding|boarding"), "Activity"] = "Surfing related"
df.loc[df["Activity"].str.contains("fishing"), "Activity"] = "Fishing related"
df.loc[df["Activity"].str.contains("swim"), "Activity"] = "Swimming related"
df.loc[df["Activity"].str.contains("diving"), "Activity"] = "Diving related"
df.loc[df["Activity"] == "Boarding related", "Activity"] = "Surfing related"
df.loc[df["Activity"].str.contains ("walking|playing"), "Activity"] = "Non water activities"

df.loc [df["Activity"] == "Non water activities", "Activity"] = "Other"  # Changed my mind, want them 2 in Others 
df.loc [df["Activity"] == "sea disaster", "Activity"] = "Other"

# %%
df.loc [ df["Activity"].str.contains ("kayaking|canoeing|rowing|maybe fell overboard|fell overboard"), "Activity" ] = "Boating related"

# %%
df.loc[ df["Activity"].isin(["wading", "bathing", "standing", "treading water", "floating"]), "Activity"] = "Swimming related"
df.loc [ df["Activity"].isin( ["snorkeling"]), "Activity" ] = "Diving related"

# %%
activity_counts = df["Activity"].value_counts()

rare_activities = activity_counts [activity_counts < 10].index
df.loc[df["Activity"].isin(rare_activities), "Activity"] = "Other"

# %%
df["Activity"].value_counts().head(20)
# Out:
# Activity
# Swimming related    1766
# Surfing related     1652
# Fishing related     1272
# Other                977
# Diving related       702
# unknown              586
# Boating related      142
# Name: count, dtype: int64

# %%
df["Fatal Y/N"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Fatal Y/N"].value_counts()
# Out:
# Fatal Y/N
# N          4950
# Y          1494
# Unknown     561
# UNKNOWN      71
#  N            7
# F             5
# M             3
# n             1
# Nq            1
# 2017          1
# Y x 2         1
# N             1
# y             1
# Name: count, dtype: int64

# %%
df["Fatal Y/N"] = df["Fatal Y/N"].str.upper().str.strip()
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\3861697453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Fatal Y/N"] = df["Fatal Y/N"].str.upper().str.strip()

# %%
df["Fatal Y/N"] = df["Fatal Y/N"].replace({"N": "No","Y": "Yes", "UNKNOWN": "Unknown"})
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\2764064334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Fatal Y/N"] = df["Fatal Y/N"].replace({"N": "No","Y": "Yes", "UNKNOWN": "Unknown"})

# %%
df["Fatal Y/N"].isna().sum()
# Out:
# np.int64(1)

# %%
df["Fatal Y/N"] = df["Fatal Y/N"].fillna ("Unknown")
# Out:
# C:\Users\mocim\AppData\Local\Temp\ipykernel_9540\2170484850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Fatal Y/N"] = df["Fatal Y/N"].fillna ("Unknown")

# %%
df.loc[ df["Fatal Y/N"].str.contains("F|M|NQ|Y X 2"), "Fatal Y/N"] = "Unknown"

# %%
df
# Out:
#                  Country          Activity  \
# 0              Australia   Fishing related
# 1                 Brazil  Swimming related
# 2                 Brazil  Swimming related
# 3              Australia   Surfing related
# 4                    USA   Surfing related
# ...                  ...               ...
# 7092           AUSTRALIA    Diving related
# 7093           AUSTRALIA    Diving related
# 7094                 USA  Swimming related
# 7095              PANAMA           unknown
# 7096  CEYLON (SRI LANKA)  Swimming related
#
#                                     Location Sex Fatal Y/N  \
# 0        Michaelmas Island King George Sound   M       Yes
# 1                          Boa Via gem beach   F        No
# 2                               PierrebBeach   M        No
# 3     Red Cliff beach Yuraygir National Park   M        No
# 4                      Cromwell's beach Oahu   M        No
# ...                                      ...  ..       ...
# 7092                             Roebuck Bay   M       Yes
# 7093                                     NaN   M       Yes
# 7094                          Ocracoke Inlet   M       Yes
# 7095                    Panama Bay 8ºN, 79ºW   M       Yes
# 7096     Below the English fort, Trincomalee   M       Yes
#
#                       Species        Type
# 0     Great White shark 4.5 m  Unprovoked
# 1              Tiger shark 3m  Unprovoked
# 2                  Bull shark  Unprovoked
# 3                 Bull shark   Unprovoked
# 4            2.4m (8ft) shark  Unprovoked
# ...                       ...         ...
# 7092                      NaN  Unprovoked
# 7093                      NaN  Unprovoked
# 7094                      NaN  Unprovoked
# 7095                      NaN  Unprovoked
# 7096                      NaN  Unprovoked
#
# [7097 rows x 7 columns]

# %%
df.to_csv("shark_clean.csv", index=False)  #copy

# %% [markdown]
# ### Hypothesis

# %%
df.groupby("Activity")["Fatal Y/N"].value_counts()
# Out:
# Activity          Fatal Y/N
# Boating related   No             84
#                   Yes            49
#                   Unknown         9
# Diving related    No            485
#                   Yes           147
#                   Unknown        70
# Fishing related   No           1010
#                   Yes           181
#                   Unknown        81
# Other             No            528
#                   Yes           343
#                   Unknown       106
# Surfing related   No           1470
#                   Yes           120
#                   Unknown        62
# Swimming related  No           1071
#                   Yes           546
#                   Unknown       149
# unknown           No            311
#                   Unknown       166
#                   Yes           109
# Name: count, dtype: int64

# %%
df_fatal["Fatal Y/N"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df_fatal["Fatal Y/N"].value_counts()
#
# NameError: name 'df_fatal' is not defined

# %%
pd.crosstab(df["Activity"], df["Fatal Y/N"])

df_fatal = df[df["Fatal Y/N"] != "Unknown"]  # Exclude Unknown from rows. But here does nothing because the row is "unknown" lowercase.

# %%
df_fatal = fatal_rate.drop ("unknown")  # Remove unknown rows

# %%
fatal_rate.index

# %%
type (df_fatal)

# %%
# Remove unknown rows from activity 
df_fatal2 = df[df["Activity"] != "unknown"]

# %%
df_fatal2["Activity"].value_counts()

# %%
fatal_rate = (pd.crosstab(df_fatal2["Activity"], df_fatal["Fatal Y/N"], normalize="index") * 100).round (2)

fatal_rate

# %%
fatal_rate.plot (kind ="bar")

# %% [markdown]
# Among the recorded shark attacks swimming, surfing and fishing related activities are the most frequent in the dataset.
# Boating related act has the highest fatal rate, followed by swimming.
#
# The highest non fatal rate is related to surfing related, followed by fishing and diving.

# %% [markdown]
# - Gender - activity
# - gender - fatal

# %%
gender_fatal ["Sex"].value_counts()

# %%
gender_fatal = df [df["Sex"] != "Unknown" ]

# %%
gender_fatal_rate = (pd.crosstab (gender_fatal ["Sex"], df_fatal ["Fatal Y/N"], normalize = "index")*100).round (2)
gender_fatal_rate

# %%
gender_fatal_rate.plot (kind = "bar")

# %% [markdown]
# Male and female had the around the same number of shark attacks recorded.
# Fatal rates are slightly higher in males than females, and non fatal rates slightly lower than female.

# %%
df ["Activity"].value_counts()

# %%
sex_activity_rate = (pd.crosstab (df_fatal2["Activity"], gender_fatal ["Sex"], normalize = "index")*100).round (2)
sex_activity_rate

# %%
gender_fatal ["Sex"].value_counts()

# %%
sex_activity_rate.plot (kind = "bar")

# Not meaningful as males registries are significantly higher than females.

# %% [markdown]
# ### VILDAN

# %%
import pandas as pd 
data = pd.read_excel("C:/Users/mocim/OneDrive/Desktop/Lessons/Week 2/Project/raw_data_shark_attacks.xls")

# %%
df = data[["Country", "Activity", "Location", "Sex", "Fatal Y/N", "Species ", "Type"]].copy()

# %%
df['Country'].value_counts()

# %%
df['Country'] = df['Country'].str.strip().str.upper()

# %%
df['Country'] = df['Country'].replace({
    'RED SEA?': 'UNKNOWN',
    'ASIA?': 'UNKNOWN',
    'CEYLON (SRI LANKA)': 'SRI LANKA'
})

# %%
df['Country'].value_counts()

# %%
df['Country'].isna().sum()

# %%
df['Country'] = df['Country'].fillna("UNKNOWN")

# %%
df['Country'].value_counts().tail(20)

# %%
country_fixes = {
    'OCEAN': 'UNKNOWN',
    'INDIAN OCEAN?': 'UNKNOWN',
    'AFRICA': 'UNKNOWN',
    'COAST OF AFRICA': 'UNKNOWN',
    'TASMAN SEA': 'UNKNOWN',
    'ITALY / CROATIA': 'UNKNOWN',
    'EQUATORIAL GUINEA / CAMEROON': 'UNKNOWN',
    'BETWEEN PORTUGAL & INDIA': 'UNKNOWN',
    'BAHREIN': 'BAHRAIN',
    'ROATAN': 'HONDURAS',
    'BRITISH NEW GUINEA': 'PAPUA NEW GUINEA',
    'SAN DOMINGO': 'DOMINICAN REPUBLIC'
}

df['Country'] = df['Country'].replace(country_fixes)

# %% [markdown]
# LOCATION

# %%
df['Location'].value_counts()

# %%
df['Location'] = df['Location'].str.strip().str.upper()

# %%
df['Location'] = df['Location'].fillna('UNKNOWN')

# %%
df['Location'].value_counts()

# %%
df['Type'].value_counts()

# %%
df['Type'] = df['Type'].str.strip().str.upper()

# %%
df['Type'] = df['Type'].fillna('UNKNOWN')

# %%
df['Type'].value_counts()

# %%
type_fixes = {
    'BOAT': 'WATERCRAFT',
    '?': 'UNKNOWN',
    'UNCONFIRMED': 'UNKNOWN',
    'UNVERIFIED': 'UNKNOWN',
    'UNDER INVESTIGATION': 'UNKNOWN',
    'QUESTIONABLE': 'UNKNOWN',
    'INVALID': 'UNKNOWN'
}

df['Type'] = df['Type'].replace(type_fixes)
df['Type'].value_counts()

# %%
df
# Out:
#                  Country          Activity  \
# 0              Australia   Fishing related
# 1                 Brazil  Swimming related
# 2                 Brazil  Swimming related
# 3              Australia   Surfing related
# 4                    USA   Surfing related
# ...                  ...               ...
# 7092           AUSTRALIA    Diving related
# 7093           AUSTRALIA    Diving related
# 7094                 USA  Swimming related
# 7095              PANAMA           unknown
# 7096  CEYLON (SRI LANKA)  Swimming related
#
#                                     Location Sex Fatal Y/N  \
# 0        Michaelmas Island King George Sound   M       Yes
# 1                          Boa Via gem beach   F        No
# 2                               PierrebBeach   M        No
# 3     Red Cliff beach Yuraygir National Park   M        No
# 4                      Cromwell's beach Oahu   M        No
# ...                                      ...  ..       ...
# 7092                             Roebuck Bay   M       Yes
# 7093                                     NaN   M       Yes
# 7094                          Ocracoke Inlet   M       Yes
# 7095                    Panama Bay 8ºN, 79ºW   M       Yes
# 7096     Below the English fort, Trincomalee   M       Yes
#
#                       Species        Type
# 0     Great White shark 4.5 m  Unprovoked
# 1              Tiger shark 3m  Unprovoked
# 2                  Bull shark  Unprovoked
# 3                 Bull shark   Unprovoked
# 4            2.4m (8ft) shark  Unprovoked
# ...                       ...         ...
# 7092                      NaN  Unprovoked
# 7093                      NaN  Unprovoked
# 7094                      NaN  Unprovoked
# 7095                      NaN  Unprovoked
# 7096                      NaN  Unprovoked
#
# [7097 rows x 7 columns]

# %%
df.nunique()
# Out:
# Country       253
# Activity        7
# Location     4639
# Sex             3
# Fatal Y/N       3
# Species      1754
# Type           14
# dtype: int64

# %% [markdown]
# ### KEAGAN
