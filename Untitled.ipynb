# %%
import pandas as pd

df = pd.read_excel('raw_data_shark_attacks.xls')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File ~/miniconda3/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# !pip install xlrd

# %%
import pandas as pd

df = pd.read_excel('raw_data_shark_attacks.xls')
df.head()
# Out:
#         Date    Year        Type    Country                  State  \
# 0   6th June  2026.0  Unprovoked  Australia      Western Australia
# 1  1st June   2026.0  Unprovoked     Brazil                Recife
# 2   1st June  2026.0  Unprovoked     Brazil  Jaboatao dos Guarapes
# 3   31st May  2026.0  Unprovoked  Australia                    NSW
# 4   30th May  2026.0  Unprovoked        USA                 Hawaii
#
#                                  Location             Activity  \
# 0     Michaelmas Island King George Sound         Spearfishing
# 1                       Boa Via gem beach             Swimming
# 2                            PierrebBeach             Swimming
# 3  Red Cliff beach Yuraygir National Park              Surfing
# 4                   Cromwell's beach Oahu  Paddling  surfboard
#
#                              Name Sex Age  ...                 Species   \
# 0                   Daniel Turpin   M  35  ...  Great White shark 4.5 m
# ...

# %%
df.shape
# Out:
# (7097, 23)

# %%
len(df)
# Out:
# 7097
