# %%
# !pip install xlrd

# %%
import pandas as pd

df = pd.read_excel('raw_data_shark_attacks.xls')
df.head()
# Out:
#         Date    Year        Type    Country                  State  \
# 0   6th June  2026.0  Unprovoked  Australia      Western Australia
# 1  1st June   2026.0  Unprovoked     Brazil                Recife
# 2   1st June  2026.0  Unprovoked     Brazil  Jaboatao dos Guarapes
# 3   31st May  2026.0  Unprovoked  Australia                    NSW
# 4   30th May  2026.0  Unprovoked        USA                 Hawaii
#
#                                  Location             Activity  \
# 0     Michaelmas Island King George Sound         Spearfishing
# 1                       Boa Via gem beach             Swimming
# 2                            PierrebBeach             Swimming
# 3  Red Cliff beach Yuraygir National Park              Surfing
# 4                   Cromwell's beach Oahu  Paddling  surfboard
#
#                              Name Sex Age  ...                 Species   \
# 0                   Daniel Turpin   M  35  ...  Great White shark 4.5 m
# ...

# %%
df.shape
# Out:
# (7097, 23)

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7097 entries, 0 to 7096
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7097 non-null   object
#  1   Year            7095 non-null   float64
#  2   Type            7079 non-null   str
#  3   Country         7047 non-null   str
#  4   State           6610 non-null   str
#  5   Location        6530 non-null   str
#  6   Activity        6514 non-null   str
#  7   Name            6879 non-null   str
#  8   Sex             6519 non-null   str
#  9   Age             4103 non-null   object
#  10  Injury          7061 non-null   str
#  11  Fatal Y/N       6536 non-null   object
#  12  Time            3570 non-null   object
#  13  Species         3966 non-null   str
#  14  Source          7077 non-null   object
#  15  pdf             6799 non-null   object
#  16  href formula    6794 non-null   str
#  17  href            6796 non-null   str
# ...

# %%
df.describe(include="all")
# Out:
#           Date         Year        Type Country    State  \
# count   7097.0  7095.000000        7079    7047     6610
# unique  6135.0          NaN          14     253      950
# top     1957.0          NaN  Unprovoked     USA  Florida
# freq       9.0          NaN        5245    2583     1192
# mean       NaN  1936.297111         NaN     NaN      NaN
# std        NaN   270.281649         NaN     NaN      NaN
# min        NaN     0.000000         NaN     NaN      NaN
# 25%        NaN  1948.000000         NaN     NaN      NaN
# 50%        NaN  1987.000000         NaN     NaN      NaN
# 75%        NaN  2010.000000         NaN     NaN      NaN
# max        NaN  2026.000000         NaN     NaN      NaN
#
#                                 Location Activity  Name   Sex     Age  ...  \
# count                               6530     6514  6879  6519  4103.0  ...
# unique                              4639     1614  5810    12   252.0  ...
# ...

# %%
df.isna().sum().sort_values(ascending=False).head(20)
# Out:
# Unnamed: 21       7096
# Unnamed: 22       7095
# Time              3527
# Species           3131
# Age               2994
# Activity           583
# Sex                578
# Location           567
# Fatal Y/N          561
# State              487
# href formula       303
# href               301
# Case Number.1      300
# Case Number        299
# pdf                298
# original order     298
# Name               218
# Country             50
# Injury              36
# Source              20
# dtype: int64

# %%
df['Country'].value_counts().head(20)
# Out:
# Country
# USA                 2583
# AUSTRALIA           1482
# SOUTH AFRICA         597
# NEW ZEALAND          144
# BAHAMAS              136
# PAPUA NEW GUINEA     136
# BRAZIL               122
# MEXICO               103
# ITALY                 72
# FIJI                  67
# NEW CALEDONIA         65
# PHILIPPINES           63
# REUNION               60
# Australia             51
# EGYPT                 49
# CUBA                  49
# SPAIN                 46
# MOZAMBIQUE            46
# INDIA                 41
# FRENCH POLYNESIA      37
# Name: count, dtype: int64

# %%
df['Activity'].value_counts().head(20)
# Out:
# Activity
# Surfing            1153
# Swimming           1018
# Fishing             494
# Spearfishing        393
# Wading              178
# Bathing             164
# Diving              151
# Snorkeling          135
# Standing            113
# Scuba diving         84
# Body boarding        63
# Body surfing         50
# Swimming             47
# Boogie boarding      42
# Kayaking             41
# Free diving          33
# Treading water       33
# Fell overboard       32
# Pearl diving         32
# Windsurfing          20
# Name: count, dtype: int64

# %%
df['Year'].value_counts().sort_index().head(20)
# Out:
# Year
# 0.0       129
# 5.0         1
# 77.0        1
# 1000.0      1
# 1500.0      1
# 1518.0      1
# 1543.0      1
# 1554.0      1
# 1555.0      1
# 1580.0      1
# 1595.0      1
# 1617.0      1
# 1637.0      1
# 1638.0      1
# 1640.0      1
# 1642.0      2
# 1691.0      1
# 1700.0      3
# 1703.0      1
# 1721.0      1
# Name: count, dtype: int64
